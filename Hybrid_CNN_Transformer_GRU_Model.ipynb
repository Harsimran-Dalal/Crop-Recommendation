# %% [markdown]
# # Hybrid CNN → Transformer → GRU Model

# %%
import pandas as pd
import numpy as np
import shap
import lime.lime_tabular
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Conv1D, GRU, Dropout, MultiHeadAttention, LayerNormalization, Add, GlobalAveragePooling1D
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical

# 1. Load dataset
df = pd.read_csv('/kaggle/input/crop-recommendation-dataset/Crop_recommendation.csv')
features = ['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']
X = df[features].values
y = df['label'].values

# Encode labels
le = LabelEncoder()
y_encoded = le.fit_transform(y)
y_cat = to_categorical(y_encoded)

# Normalize
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)
X_seq = X_scaled.reshape((X_scaled.shape[0], 7, 1))  # sequence-like shape

# Split
X_train, X_test, y_train, y_test = train_test_split(X_seq, y_cat, test_size=0.2, random_state=42)

# 2. Hybrid CNN → Transformer → GRU Model
def hybrid_model(input_shape, num_classes, d_model=64, num_heads=4, ff_dim=128):
    inp = Input(shape=input_shape)

    # CNN: Local feature extraction
    x = Conv1D(filters=64, kernel_size=1, activation='relu')(inp)

    # Transformer block
    attn_output = MultiHeadAttention(num_heads=num_heads, key_dim=d_model)(x, x)
    attn_output = Add()([x, attn_output])
    attn_output = LayerNormalization()(attn_output)

    # Feed-forward
    ff = Dense(ff_dim, activation='relu')(attn_output)
    ff = Dense(d_model)(ff)
    x = Add()([attn_output, ff])
    x = LayerNormalization()(x)

    # GRU
    x = GRU(64, return_sequences=False)(x)
    x = Dropout(0.3)(x)

    # Output
    x = Dense(64, activation='relu')(x)
    out = Dense(num_classes, activation='softmax')(x)

    return Model(inputs=inp, outputs=out)

model = hybrid_model(input_shape=(7, 1), num_classes=y_cat.shape[1])
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# 3. Train
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
history = model.fit(X_train, y_train, validation_split=0.2, epochs=100, callbacks=[early_stop], verbose=1)

# 4. Evaluate
loss, acc = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {acc:.4f}")

y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(y_test, axis=1)

print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=le.classes_))

# 5. Confusion Matrix
plt.figure(figsize=(12, 8))
cm = confusion_matrix(y_true, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=le.classes_, yticklabels=le.classes_)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.tight_layout()
plt.show()

# 6. Accuracy & Loss Plot
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train', marker='o')
plt.plot(history.history['val_accuracy'], label='Val', marker='o')
plt.title("Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.grid(True)
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss', marker='o')
plt.plot(history.history['val_loss'], label='Val Loss', marker='o')
plt.title("Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 10s 35ms/step - accuracy: 0.0660 - loss: 3.1234 - val_accuracy: 0.1648 - val_loss: 2.8844
# Epoch 2/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.2005 - loss: 2.6464 - val_accuracy: 0.3494 - val_loss: 1.9872
# Epoch 3/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.4117 - loss: 1.8120 - val_accuracy: 0.4773 - val_loss: 1.4139
# Epoch 4/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5297 - loss: 1.3381 - val_accuracy: 0.6932 - val_loss: 1.0034
# Epoch 5/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6920 - loss: 0.9870 - val_accuracy: 0.7699 - val_loss: 0.7125
# Epoch 6/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7699 - loss: 0.7527 - val_accuracy: 0.8125 - val_loss: 0.5913
# Epoch 7/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8374 - loss: 0.5722 - val_accuracy: 0.8864 - val_loss: 0.4135
# Epoch 8/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8753 - loss: 0.4579 - val_accuracy: 0.8977 - val_loss: 0.3555
# Epoch 9/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8876 - loss: 0.3888 - val_accuracy: 0.9205 - val_loss: 0.2476
# Epoch 10/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9391 - loss: 0.2618 - val_accuracy: 0.9006 - val_loss: 0.2759
# Epoch 11/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9216 - loss: 0.2577 - val_accuracy: 0.9290 - val_loss: 0.2219
# Epoch 12/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9555 - loss: 0.1824 - val_accuracy: 0.9602 - val_loss: 0.1255
# Epoch 13/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9629 - loss: 0.1599 - val_accuracy: 0.9489 - val_loss: 0.1306
# Epoch 14/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9689 - loss: 0.1338 - val_accuracy: 0.9858 - val_loss: 0.0786
# Epoch 15/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9793 - loss: 0.1019 - val_accuracy: 0.9602 - val_loss: 0.1089
# Epoch 16/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9601 - loss: 0.1356 - val_accuracy: 0.9574 - val_loss: 0.1165
# Epoch 17/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9781 - loss: 0.0905 - val_accuracy: 0.9801 - val_loss: 0.0721
# Epoch 18/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9713 - loss: 0.0957 - val_accuracy: 0.9801 - val_loss: 0.0562
# Epoch 19/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9781 - loss: 0.0923 - val_accuracy: 0.9574 - val_loss: 0.0920
# Epoch 20/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9781 - loss: 0.0931 - val_accuracy: 0.9915 - val_loss: 0.0442
# Epoch 21/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9739 - loss: 0.0883 - val_accuracy: 0.9830 - val_loss: 0.0440
# Epoch 22/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9824 - loss: 0.0678 - val_accuracy: 0.9886 - val_loss: 0.0389
# Epoch 23/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9863 - loss: 0.0520 - val_accuracy: 0.9886 - val_loss: 0.0331
# Epoch 24/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9889 - loss: 0.0419 - val_accuracy: 0.9858 - val_loss: 0.0483
# Epoch 25/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9831 - loss: 0.0674 - val_accuracy: 0.9858 - val_loss: 0.0424
# Epoch 26/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9902 - loss: 0.0389 - val_accuracy: 0.9915 - val_loss: 0.0268
# Epoch 27/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9879 - loss: 0.0413 - val_accuracy: 0.9631 - val_loss: 0.0840
# Epoch 28/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9872 - loss: 0.0498 - val_accuracy: 0.9830 - val_loss: 0.0457
# Epoch 29/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9843 - loss: 0.0553 - val_accuracy: 0.9716 - val_loss: 0.0768
# Epoch 30/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9783 - loss: 0.0687 - val_accuracy: 0.9858 - val_loss: 0.0526
# Epoch 31/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9866 - loss: 0.0515 - val_accuracy: 0.9943 - val_loss: 0.0260
# Epoch 32/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9925 - loss: 0.0310 - val_accuracy: 0.9915 - val_loss: 0.0344
# Epoch 33/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9946 - loss: 0.0240 - val_accuracy: 0.9886 - val_loss: 0.0275
# Epoch 34/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9919 - loss: 0.0323 - val_accuracy: 0.9119 - val_loss: 0.3092
# Epoch 35/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9548 - loss: 0.1348 - val_accuracy: 0.9858 - val_loss: 0.0499
# Epoch 36/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9793 - loss: 0.0863 - val_accuracy: 0.9886 - val_loss: 0.0368
# Epoch 37/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9921 - loss: 0.0302 - val_accuracy: 0.9858 - val_loss: 0.0352
# Epoch 38/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9725 - loss: 0.0855 - val_accuracy: 0.9858 - val_loss: 0.0388
# Epoch 39/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9752 - loss: 0.0628 - val_accuracy: 0.9886 - val_loss: 0.0458
# Epoch 40/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9791 - loss: 0.0598 - val_accuracy: 0.9830 - val_loss: 0.0404
# Epoch 41/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9867 - loss: 0.0368 - val_accuracy: 0.9886 - val_loss: 0.0344
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9796 - loss: 0.0456
# Test Accuracy: 0.9818
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        23
#       banana       1.00      1.00      1.00        21
#    blackgram       1.00      1.00      1.00        20
#     chickpea       1.00      1.00      1.00        26
#      coconut       1.00      1.00      1.00        27
#       coffee       0.94      1.00      0.97        17
#       cotton       0.94      1.00      0.97        17
#       grapes       1.00      1.00      1.00        14
#         jute       0.84      0.91      0.87        23
#  kidneybeans       1.00      1.00      1.00        20
#       lentil       0.92      1.00      0.96        11
#        maize       1.00      0.95      0.98        21
#        mango       1.00      1.00      1.00        19
#    mothbeans       1.00      0.96      0.98        24
#     mungbean       1.00      1.00      1.00        19
#    muskmelon       1.00      1.00      1.00        17
#       orange       1.00      1.00      1.00        14
#       papaya       1.00      1.00      1.00        23
#   pigeonpeas       1.00      1.00      1.00        23
#  pomegranate       1.00      1.00      1.00        23
#         rice       0.94      0.79      0.86        19
#   watermelon       1.00      1.00      1.00        19
#
#     accuracy                           0.98       440
#    macro avg       0.98      0.98      0.98       440
# weighted avg       0.98      0.98      0.98       440

# %%
# 7. SHAP Explainability
print("🔍 SHAP Explainability:")
X_flat = X_seq.reshape(X_seq.shape[0], X_seq.shape[1])
explainer = shap.KernelExplainer(lambda x: model.predict(x.reshape(x.shape[0], 7, 1)), X_flat[:50])
shap_values = explainer.shap_values(X_flat[:1])
shap.summary_plot(shap_values, X_flat[:1], feature_names=features)

# 8. LIME Explainability
print("🔍 LIME Explainability:")
explainer_lime = lime.lime_tabular.LimeTabularExplainer(
    training_data=X_flat,
    feature_names=features,
    class_names=le.classes_,
    mode='classification'
)

lime_exp = explainer_lime.explain_instance(
    data_row=X_flat[0],
    predict_fn=lambda x: model.predict(x.reshape(x.shape[0], 7, 1)),
    num_features=7
)
lime_exp.show_in_notebook()

# 9. Save model
model.save('/mnt/data/hybrid_cnn_transformer_gru.h5')
print("✅ Model saved as 'hybrid_cnn_transformer_gru.h5'")
