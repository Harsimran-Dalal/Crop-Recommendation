# %% [markdown]
# # TabTransformer-style attention blocks + GRU

# %% [markdown]
# ## TabTransformer:
#
# ### Uses sequence attention: input → treat each feature as a sequence step → full attention between features.

# %%
import pandas as pd
import numpy as np
import shap
import lime.lime_tabular
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

import tensorflow as tf
from tensorflow.keras.layers import (Input, Dense, Reshape, GRU, Dropout, 
                                     MultiHeadAttention, LayerNormalization, Add)
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping

# 1️⃣ Load and preprocess dataset
df = pd.read_csv('/kaggle/input/crop-recommendation-dataset/Crop_recommendation.csv')
features = ['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']
X = df[features].values
y = df['label'].values

# Encode labels
le = LabelEncoder()
y_encoded = le.fit_transform(y)
y_cat = to_categorical(y_encoded)
num_classes = y_cat.shape[1]

# Normalize features
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Reshape for sequence modeling (batch, timesteps=7, features=1)
X_seq = X_scaled.reshape((X_scaled.shape[0], 7))

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_seq, y_cat, test_size=0.2, random_state=42)

# 2️⃣ Model Parameters
num_features = 7
d_model = 64
num_heads = 4
dropout_rate = 0.1

# 3️⃣ Model Definition
inputs = Input(shape=(num_features,))  # (7,)

# ➕ Reshape to (7, 1) to simulate token embeddings
x = Reshape((num_features, 1))(inputs)  # (batch_size, 7, 1)

# ➕ Dense projection to d_model for TabTransformer-like attention
x = Dense(d_model)(x)  # (batch_size, 7, d_model)

# 🔁 Multi-head self-attention
attn_output = MultiHeadAttention(num_heads=num_heads, key_dim=d_model)(x, x)
x = Add()([x, attn_output])
x = LayerNormalization()(x)

# 🔁 Feed-forward block
ff = Dense(d_model * 2, activation='relu')(x)
ff = Dense(d_model)(ff)
x = Add()([x, ff])
x = LayerNormalization()(x)

# 🔁 GRU for temporal modeling
x = GRU(64, return_sequences=False)(x)

# 🔚 Classification head
x = Dropout(dropout_rate)(x)
x = Dense(64, activation='relu')(x)
outputs = Dense(num_classes, activation='softmax')(x)

# 🚀 Build model
model = Model(inputs=inputs, outputs=outputs)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()

# 4️⃣ Train
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
history = model.fit(X_train, y_train, validation_split=0.2, epochs=100, batch_size=32, 
                    callbacks=[early_stop], verbose=1)

# 5️⃣ Evaluate
loss, acc = model.evaluate(X_test, y_test)
print(f"\n✅ Test Accuracy: {acc:.4f}")

# 6️⃣ Predictions & Classification Report
y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(y_test, axis=1)

print("\n📋 Classification Report:")
print(classification_report(y_true, y_pred, target_names=le.classes_))

# 🔲 Confusion Matrix
plt.figure(figsize=(12, 8))
cm = confusion_matrix(y_true, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=le.classes_, yticklabels=le.classes_)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.tight_layout()
plt.show()

# 📈 Accuracy & Loss Plot
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Acc', marker='o')
plt.plot(history.history['val_accuracy'], label='Val Acc', marker='o')
plt.title("Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.grid(True)
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss', marker='o')
plt.plot(history.history['val_loss'], label='Val Loss', marker='o')
plt.title("Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 7)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_1 (Reshape) │ (None, 7, 1)      │          0 │ input_layer_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 7, 64)     │        128 │ reshape_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 7, 64)     │     66,368 │ dense_5[0][0],    │
# │ (MultiHeadAttentio… │                   │            │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 7, 64)     │          0 │ dense_5[0][0],    │
# │                     │                   │            │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 7, 64)     │        128 │ add_2[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 7, 128)    │      8,320 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 7, 64)     │      8,256 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 7, 64)     │          0 │ layer_normalizat… │
# │                     │                   │            │ dense_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 7, 64)     │        128 │ add_3[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gru_1 (GRU)         │ (None, 64)        │     24,960 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 64)        │          0 │ gru_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 64)        │      4,160 │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 22)        │      1,430 │ dense_8[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 113,878 (444.84 KB)
#  Trainable params: 113,878 (444.84 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 10s 37ms/step - accuracy: 0.1096 - loss: 3.0309 - val_accuracy: 0.2500 - val_loss: 2.5139
# Epoch 2/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.3170 - loss: 2.2852 - val_accuracy: 0.4489 - val_loss: 1.7562
# Epoch 3/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.5225 - loss: 1.4763 - val_accuracy: 0.7358 - val_loss: 1.0155
# Epoch 4/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.7209 - loss: 0.9441 - val_accuracy: 0.8210 - val_loss: 0.6738
# Epoch 5/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8322 - loss: 0.6243 - val_accuracy: 0.8580 - val_loss: 0.4699
# Epoch 6/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8835 - loss: 0.4484 - val_accuracy: 0.8977 - val_loss: 0.3560
# Epoch 7/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9253 - loss: 0.3188 - val_accuracy: 0.9148 - val_loss: 0.2906
# Epoch 8/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9567 - loss: 0.2354 - val_accuracy: 0.9432 - val_loss: 0.2018
# Epoch 9/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9544 - loss: 0.2019 - val_accuracy: 0.9233 - val_loss: 0.2089
# Epoch 10/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9696 - loss: 0.1303 - val_accuracy: 0.9744 - val_loss: 0.1020
# Epoch 11/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9817 - loss: 0.0975 - val_accuracy: 0.9688 - val_loss: 0.0860
# Epoch 12/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9846 - loss: 0.0696 - val_accuracy: 0.9716 - val_loss: 0.0865
# Epoch 13/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9873 - loss: 0.0669 - val_accuracy: 0.9830 - val_loss: 0.0653
# Epoch 14/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9765 - loss: 0.0707 - val_accuracy: 0.9858 - val_loss: 0.0563
# Epoch 15/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9892 - loss: 0.0453 - val_accuracy: 0.9716 - val_loss: 0.0737
# Epoch 16/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9894 - loss: 0.0513 - val_accuracy: 0.9830 - val_loss: 0.0604
# Epoch 17/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9855 - loss: 0.0493 - val_accuracy: 0.9858 - val_loss: 0.0559
# Epoch 18/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9824 - loss: 0.0554 - val_accuracy: 0.9545 - val_loss: 0.0958
# Epoch 19/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9749 - loss: 0.0811 - val_accuracy: 0.9716 - val_loss: 0.0693
# Epoch 20/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9704 - loss: 0.0831 - val_accuracy: 0.9688 - val_loss: 0.0937
# Epoch 21/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9801 - loss: 0.0674 - val_accuracy: 0.9801 - val_loss: 0.0648
# Epoch 22/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9868 - loss: 0.0517 - val_accuracy: 0.9858 - val_loss: 0.0385
# Epoch 23/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9947 - loss: 0.0252 - val_accuracy: 0.9915 - val_loss: 0.0409
# Epoch 24/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9955 - loss: 0.0227 - val_accuracy: 0.9858 - val_loss: 0.0446
# Epoch 25/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9929 - loss: 0.0224 - val_accuracy: 0.9858 - val_loss: 0.0395
# Epoch 26/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9930 - loss: 0.0236 - val_accuracy: 0.9915 - val_loss: 0.0325
# Epoch 27/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9901 - loss: 0.0328 - val_accuracy: 0.9574 - val_loss: 0.1056
# Epoch 28/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9850 - loss: 0.0492 - val_accuracy: 0.9886 - val_loss: 0.0477
# Epoch 29/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9767 - loss: 0.0557 - val_accuracy: 0.9801 - val_loss: 0.0727
# Epoch 30/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9841 - loss: 0.0473 - val_accuracy: 0.9886 - val_loss: 0.0373
# Epoch 31/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9898 - loss: 0.0282 - val_accuracy: 0.9858 - val_loss: 0.0392
# Epoch 32/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9961 - loss: 0.0259 - val_accuracy: 0.9915 - val_loss: 0.0311
# Epoch 33/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9919 - loss: 0.0306 - val_accuracy: 0.9858 - val_loss: 0.0429
# Epoch 34/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9889 - loss: 0.0431 - val_accuracy: 0.9886 - val_loss: 0.0444
# Epoch 35/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9921 - loss: 0.0304 - val_accuracy: 0.9801 - val_loss: 0.0452
# Epoch 36/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9855 - loss: 0.0299 - val_accuracy: 0.9886 - val_loss: 0.0390
# Epoch 37/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9678 - loss: 0.0877 - val_accuracy: 0.9659 - val_loss: 0.0701
# Epoch 38/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9941 - loss: 0.0254 - val_accuracy: 0.9716 - val_loss: 0.0702
# Epoch 39/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9876 - loss: 0.0272 - val_accuracy: 0.9773 - val_loss: 0.0716
# Epoch 40/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9929 - loss: 0.0237 - val_accuracy: 0.9943 - val_loss: 0.0307
# Epoch 41/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9967 - loss: 0.0162 - val_accuracy: 0.9886 - val_loss: 0.0336
# Epoch 42/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9954 - loss: 0.0148 - val_accuracy: 0.9886 - val_loss: 0.0356
# Epoch 43/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9925 - loss: 0.0241 - val_accuracy: 0.9773 - val_loss: 0.0516
# Epoch 44/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9958 - loss: 0.0129 - val_accuracy: 0.9915 - val_loss: 0.0371
# Epoch 45/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9861 - loss: 0.0327 - val_accuracy: 0.9858 - val_loss: 0.0451
# Epoch 46/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9905 - loss: 0.0258 - val_accuracy: 0.9773 - val_loss: 0.0548
# Epoch 47/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9844 - loss: 0.0494 - val_accuracy: 0.9830 - val_loss: 0.0423
# Epoch 48/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9928 - loss: 0.0266 - val_accuracy: 0.9801 - val_loss: 0.0635
# Epoch 49/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9903 - loss: 0.0388 - val_accuracy: 0.9972 - val_loss: 0.0242
# Epoch 50/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9922 - loss: 0.0180 - val_accuracy: 0.9858 - val_loss: 0.0504
# Epoch 51/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9920 - loss: 0.0248 - val_accuracy: 0.9915 - val_loss: 0.0355
# Epoch 52/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9955 - loss: 0.0150 - val_accuracy: 0.9886 - val_loss: 0.0340
# Epoch 53/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9950 - loss: 0.0143 - val_accuracy: 0.9915 - val_loss: 0.0452
# Epoch 54/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9914 - loss: 0.0254 - val_accuracy: 0.9886 - val_loss: 0.0305
# Epoch 55/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9914 - loss: 0.0211 - val_accuracy: 0.9858 - val_loss: 0.0555
# Epoch 56/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9914 - loss: 0.0194 - val_accuracy: 0.9886 - val_loss: 0.0393
# Epoch 57/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9960 - loss: 0.0161 - val_accuracy: 0.9659 - val_loss: 0.1067
# Epoch 58/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9732 - loss: 0.0793 - val_accuracy: 0.9716 - val_loss: 0.0787
# Epoch 59/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9895 - loss: 0.0353 - val_accuracy: 0.9858 - val_loss: 0.0474
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9847 - loss: 0.0721
#
# ✅ Test Accuracy: 0.9818
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        23
#       banana       1.00      1.00      1.00        21
#    blackgram       1.00      1.00      1.00        20
#     chickpea       1.00      1.00      1.00        26
#      coconut       1.00      1.00      1.00        27
#       coffee       0.94      1.00      0.97        17
#       cotton       0.94      1.00      0.97        17
#       grapes       1.00      1.00      1.00        14
#         jute       0.91      0.91      0.91        23
#  kidneybeans       1.00      1.00      1.00        20
#       lentil       0.79      1.00      0.88        11
#        maize       1.00      0.95      0.98        21
#        mango       1.00      1.00      1.00        19
#    mothbeans       1.00      0.88      0.93        24
#     mungbean       1.00      1.00      1.00        19
#    muskmelon       1.00      1.00      1.00        17
#       orange       1.00      1.00      1.00        14
#       papaya       1.00      1.00      1.00        23
#   pigeonpeas       1.00      1.00      1.00        23
#  pomegranate       1.00      1.00      1.00        23
#         rice       0.94      0.89      0.92        19
#   watermelon       1.00      1.00      1.00        19
#
#     accuracy                           0.98       440
#    macro avg       0.98      0.98      0.98       440
# weighted avg       0.98      0.98      0.98       440
