# %% [markdown]
# # Hybrid CNN → Transformer → GRU Model

# %%
import pandas as pd
import numpy as np
import shap
import lime.lime_tabular
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Conv1D, GRU, Dropout, MultiHeadAttention, LayerNormalization, Add, GlobalAveragePooling1D
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical

# 1. Load dataset
df = pd.read_csv('/kaggle/input/crop-recommendation-dataset/Crop_recommendation.csv')
features = ['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']
X = df[features].values
y = df['label'].values

# Encode labels
le = LabelEncoder()
y_encoded = le.fit_transform(y)
y_cat = to_categorical(y_encoded)

# Normalize
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)
X_seq = X_scaled.reshape((X_scaled.shape[0], 7, 1))  # sequence-like shape

# Split
X_train, X_test, y_train, y_test = train_test_split(X_seq, y_cat, test_size=0.2, random_state=42)

# 2. Hybrid CNN → Transformer → GRU Model
def hybrid_model(input_shape, num_classes, d_model=64, num_heads=4, ff_dim=128):
    inp = Input(shape=input_shape)

    # CNN: Local feature extraction
    x = Conv1D(filters=64, kernel_size=1, activation='relu')(inp)

    # Transformer block
    attn_output = MultiHeadAttention(num_heads=num_heads, key_dim=d_model)(x, x)
    attn_output = Add()([x, attn_output])
    attn_output = LayerNormalization()(attn_output)

    # Feed-forward
    ff = Dense(ff_dim, activation='relu')(attn_output)
    ff = Dense(d_model)(ff)
    x = Add()([attn_output, ff])
    x = LayerNormalization()(x)

    # GRU
    x = GRU(64, return_sequences=False)(x)
    x = Dropout(0.3)(x)

    # Output
    x = Dense(64, activation='relu')(x)
    out = Dense(num_classes, activation='softmax')(x)

    return Model(inputs=inp, outputs=out)

model = hybrid_model(input_shape=(7, 1), num_classes=y_cat.shape[1])
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# 3. Train
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
history = model.fit(X_train, y_train, validation_split=0.2, epochs=100, callbacks=[early_stop], verbose=1)

# 4. Evaluate
loss, acc = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {acc:.4f}")

y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(y_test, axis=1)

print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=le.classes_))

# 5. Confusion Matrix
plt.figure(figsize=(12, 8))
cm = confusion_matrix(y_true, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=le.classes_, yticklabels=le.classes_)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.tight_layout()
plt.show()

# 6. Accuracy & Loss Plot
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train', marker='o')
plt.plot(history.history['val_accuracy'], label='Val', marker='o')
plt.title("Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.grid(True)
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss', marker='o')
plt.plot(history.history['val_loss'], label='Val Loss', marker='o')
plt.title("Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

model.save('hybrid_cnn_transformer_gru.h5')
print("Model saved as 'hybrid_cnn_transformer_gru.h5'")
# Out:
# 2025-11-11 09:43:05.254560: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762854185.582093      38 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762854185.680295      38 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-11 09:43:22.063582: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Epoch 1/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.0665 - loss: 3.0854 - val_accuracy: 0.1364 - val_loss: 2.7369
# Epoch 2/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.1834 - loss: 2.5976 - val_accuracy: 0.4716 - val_loss: 1.8707
# Epoch 3/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.4109 - loss: 1.8229 - val_accuracy: 0.5312 - val_loss: 1.3510
# Epoch 4/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5915 - loss: 1.3087 - val_accuracy: 0.6790 - val_loss: 0.9358
# Epoch 5/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6888 - loss: 0.9816 - val_accuracy: 0.7926 - val_loss: 0.7091
# Epoch 6/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7370 - loss: 0.7656 - val_accuracy: 0.7670 - val_loss: 0.6225
# Epoch 7/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7873 - loss: 0.6352 - val_accuracy: 0.8807 - val_loss: 0.4276
# Epoch 8/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8796 - loss: 0.4460 - val_accuracy: 0.8580 - val_loss: 0.3846
# Epoch 9/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8797 - loss: 0.3948 - val_accuracy: 0.9205 - val_loss: 0.2642
# Epoch 10/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9229 - loss: 0.3161 - val_accuracy: 0.9318 - val_loss: 0.2268
# Epoch 11/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9288 - loss: 0.2455 - val_accuracy: 0.9119 - val_loss: 0.2604
# Epoch 12/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9203 - loss: 0.2519 - val_accuracy: 0.9489 - val_loss: 0.1600
# Epoch 13/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9549 - loss: 0.1962 - val_accuracy: 0.9176 - val_loss: 0.2137
# Epoch 14/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9390 - loss: 0.2031 - val_accuracy: 0.9432 - val_loss: 0.1478
# Epoch 15/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9543 - loss: 0.1391 - val_accuracy: 0.9716 - val_loss: 0.1120
# Epoch 16/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.
# Epoch 50/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9862 - loss: 0.0356 - val_accuracy: 0.9915 - val_loss: 0.0309
# Epoch 51/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9930 - loss: 0.0247 - val_accuracy: 0.9830 - val_loss: 0.0477
# Epoch 52/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9934 - loss: 0.0258 - val_accuracy: 0.9886 - val_loss: 0.0311
# Epoch 53/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9935 - loss: 0.0224 - val_accuracy: 0.9943 - val_loss: 0.0259
# Epoch 54/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9952 - loss: 0.0226 - val_accuracy: 0.9886 - val_loss: 0.0310
# Epoch 55/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9955 - loss: 0.0231 - val_accuracy: 0.9915 - val_loss: 0.0241
# Epoch 56/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9904 - loss: 0.0209 - val_accuracy: 0.9631 - val_loss: 0.1056
# Epoch 57/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9888 - loss: 0.0400 - val_accuracy: 0.9915 - val_loss: 0.0279
# Epoch 58/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9934 - loss: 0.0212 - val_accuracy: 0.9915 - val_loss: 0.0352
# Epoch 59/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9944 - loss: 0.0189 - val_accuracy: 0.9659 - val_loss: 0.0971
# Epoch 60/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9931 - loss: 0.0309 - val_accuracy: 0.9830 - val_loss: 0.0410
# Epoch 61/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9835 - loss: 0.0566 - val_accuracy: 0.9830 - val_loss: 0.0479
# Epoch 62/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9862 - loss: 0.0314 - val_accuracy: 0.9886 - val_loss: 0.0406
# Epoch 63/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9887 - loss: 0.0292 - val_accuracy: 0.9858 - val_loss: 0.0426
# Epoch 64/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9913 - loss: 0.0326 - val_accuracy: 0.9858 - val_loss: 0.0538
# Epoch 65/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9906 - loss: 0.0380 - val_accuracy: 0.9886 - val_loss: 0.0464
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9833 - loss: 0.0549
# Test Accuracy: 0.9795
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        23
#       banana       1.00      1.00      1.00        21
#    blackgram       1.00      1.00      1.00        20
#     chickpea       1.00      1.00      1.00        26
#      coconut       1.00      1.00      1.00        27
#       coffee       0.94      0.94      0.94        17
#       cotton       1.00      1.00      1.00        17
#       grapes       1.00      1.00      1.00        14
#         jute       0.84      0.91      0.87        23
#  kidneybeans       1.00      1.00      1.00        20
#       lentil       0.79      1.00      0.88        11
#        maize       1.00      1.00      1.00        21
#        mango       1.00      1.00      1.00        19
#    mothbeans       1.00      0.88      0.93        24
#     mungbean       1.00      1.00      1.00        19
#    muskmelon       1.00      1.00      1.00        17
#       orange       1.00      1.00      1.00        14
#       papaya       1.00      1.00      1.00        23
#   pigeonpeas       1.00      1.00      1.00        23
#  pomegranate       1.00      1.00      1.00        23
#         rice       0.94      0.84      0.89        19
#   watermelon       1.00      1.00      1.00        19
#
#     accuracy                           0.98       440
#    macro avg       0.98      0.98      0.98       440
# weighted avg       0.98      0.98      0.98       440
# Model saved as 'hybrid_cnn_transformer_gru.h5'

# %%
# 7. SHAP Explainability
print("🔍 SHAP Explainability:")
X_flat = X_seq.reshape(X_seq.shape[0], X_seq.shape[1])
explainer = shap.KernelExplainer(lambda x: model.predict(x.reshape(x.shape[0], 7, 1)), X_flat[:50])
shap_values = explainer.shap_values(X_flat[:1])
shap.summary_plot(shap_values, X_flat[:1], feature_names=features)

# 8. LIME Explainability
print("🔍 LIME Explainability:")
explainer_lime = lime.lime_tabular.LimeTabularExplainer(
    training_data=X_flat,
    feature_names=features,
    class_names=le.classes_,
    mode='classification'
)

lime_exp = explainer_lime.explain_instance(
    data_row=X_flat[0],
    predict_fn=lambda x: model.predict(x.reshape(x.shape[0], 7, 1)),
    num_features=7
)
lime_exp.show_in_notebook()
