# %% [markdown]
# # Hybrid XGBoost → Transformer → LSTM

# %%
import pandas as pd
import numpy as np
import shap
import lime.lime_tabular
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

import xgboost as xgb
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, LSTM, Dropout, MultiHeadAttention, LayerNormalization, Add
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping

# 1. Load and preprocess dataset
df = pd.read_csv('/kaggle/input/crop-recommendation-dataset/Crop_recommendation.csv')
features = ['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']
X = df[features].values
y = df['label'].values

# Label Encoding
le = LabelEncoder()
y_encoded = le.fit_transform(y)
y_cat = to_categorical(y_encoded)

# Scaling
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Split for XGBoost
X_train_xgb, X_test_xgb, y_train_xgb, y_test_xgb = train_test_split(X_scaled, y_encoded, test_size=0.2, random_state=42)

# 2. Train XGBoost for feature selection
xgb_model = xgb.XGBClassifier(n_estimators=100, objective='multi:softmax', num_class=len(np.unique(y_encoded)))
xgb_model.fit(X_train_xgb, y_train_xgb)

# Get top N features by importance
importances = xgb_model.feature_importances_
top_n = 5
top_features_idx = np.argsort(importances)[::-1][:top_n]

X_selected = X_scaled[:, top_features_idx]
X_selected_seq = X_selected.reshape((X_selected.shape[0], top_n, 1))

# Final split for DL pipeline
X_train, X_test, y_train, y_test = train_test_split(X_selected_seq, y_cat, test_size=0.2, random_state=42)

# 3. XGBoost → Transformer → LSTM Model
def hybrid_model(input_shape, num_classes, d_model=64, num_heads=2, ff_dim=128):
    inp = Input(shape=input_shape)

    # Linear projection
    x = Dense(d_model)(inp)

    # Transformer block
    attn = MultiHeadAttention(num_heads=num_heads, key_dim=d_model)(x, x)
    x = Add()([x, attn])
    x = LayerNormalization()(x)

    ff = Dense(ff_dim, activation='relu')(x)
    ff = Dense(d_model)(ff)
    x = Add()([x, ff])
    x = LayerNormalization()(x)

    # LSTM block
    x = LSTM(64)(x)
    x = Dropout(0.3)(x)
    x = Dense(64, activation='relu')(x)
    out = Dense(num_classes, activation='softmax')(x)

    return Model(inputs=inp, outputs=out)

model = hybrid_model(input_shape=(top_n, 1), num_classes=y_cat.shape[1])
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# 4. Train model
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
history = model.fit(X_train, y_train, validation_split=0.2, epochs=100, callbacks=[early_stop], verbose=1)

# 5. Evaluation
loss, acc = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {acc:.4f}")

y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(y_test, axis=1)

print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=le.classes_))

# 6. Confusion Matrix
plt.figure(figsize=(12, 8))
cm = confusion_matrix(y_true, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=le.classes_, yticklabels=le.classes_)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.tight_layout()
plt.show()

# 7. Accuracy & Loss Plot
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train', marker='o')
plt.plot(history.history['val_accuracy'], label='Val', marker='o')
plt.title("Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.grid(True)
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss', marker='o')
plt.plot(history.history['val_loss'], label='Val Loss', marker='o')
plt.title("Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.0808 - loss: 3.0548 - val_accuracy: 0.1648 - val_loss: 2.7007
# Epoch 2/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.2077 - loss: 2.5706 - val_accuracy: 0.5682 - val_loss: 1.6840
# Epoch 3/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.5229 - loss: 1.6022 - val_accuracy: 0.7472 - val_loss: 0.9654
# Epoch 4/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7348 - loss: 0.9496 - val_accuracy: 0.8750 - val_loss: 0.5661
# Epoch 5/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8155 - loss: 0.6378 - val_accuracy: 0.9432 - val_loss: 0.3754
# Epoch 6/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8703 - loss: 0.4507 - val_accuracy: 0.9489 - val_loss: 0.2596
# Epoch 7/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8919 - loss: 0.3594 - val_accuracy: 0.9688 - val_loss: 0.1878
# Epoch 8/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9415 - loss: 0.2495 - val_accuracy: 0.9773 - val_loss: 0.1355
# Epoch 9/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9459 - loss: 0.2079 - val_accuracy: 0.9602 - val_loss: 0.1294
# Epoch 10/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9380 - loss: 0.2121 - val_accuracy: 0.9830 - val_loss: 0.0792
# Epoch 11/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9683 - loss: 0.1341 - val_accuracy: 0.9091 - val_loss: 0.2895
# Epoch 12/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9230 - loss: 0.2597 - val_accuracy: 0.9545 - val_loss: 0.1519
# Epoch 13/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9602 - loss: 0.1407 - val_accuracy: 0.9801 - val_loss: 0.0776
# Epoch 14/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9533 - loss: 0.1430 - val_accuracy: 0.9602 - val_loss: 0.0918
# Epoch 15/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9618 - loss: 0.1246 - val_accuracy: 0.9716 - val_loss: 0.0794
# Epoch 16/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9721 - loss: 0.1051 - val_accuracy: 0.9489 - val_loss: 0.1214
# Epoch 17/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9636 - loss: 0.1229 - val_accuracy: 0.9830 - val_loss: 0.0624
# Epoch 18/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9607 - loss: 0.1140 - val_accuracy: 0.9830 - val_loss: 0.0620
# Epoch 19/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9734 - loss: 0.0862 - val_accuracy: 0.9886 - val_loss: 0.0504
# Epoch 20/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9643 - loss: 0.1257 - val_accuracy: 0.9716 - val_loss: 0.0588
# Epoch 21/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9771 - loss: 0.0729 - val_accuracy: 0.9659 - val_loss: 0.0868
# Epoch 22/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9608 - loss: 0.0987 - val_accuracy: 0.9574 - val_loss: 0.1340
# Epoch 23/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9486 - loss: 0.1614 - val_accuracy: 0.9830 - val_loss: 0.0547
# Epoch 24/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9641 - loss: 0.1013 - val_accuracy: 0.9716 - val_loss: 0.0698
# Epoch 25/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9778 - loss: 0.0734 - val_accuracy: 0.9773 - val_loss: 0.0674
# Epoch 26/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9738 - loss: 0.0662 - val_accuracy: 0.9744 - val_loss: 0.0550
# Epoch 27/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9786 - loss: 0.0698 - val_accuracy: 0.9858 - val_loss: 0.0299
# Epoch 28/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9759 - loss: 0.0710 - val_accuracy: 0.9688 - val_loss: 0.0939
# Epoch 29/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9740 - loss: 0.0693 - val_accuracy: 0.9631 - val_loss: 0.0824
# Epoch 30/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9716 - loss: 0.0746 - val_accuracy: 0.9886 - val_loss: 0.0461
# Epoch 31/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9745 - loss: 0.0633 - val_accuracy: 0.9688 - val_loss: 0.0579
# Epoch 32/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9812 - loss: 0.0563 - val_accuracy: 0.9830 - val_loss: 0.0425
# Epoch 33/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9809 - loss: 0.0452 - val_accuracy: 0.9773 - val_loss: 0.0423
# Epoch 34/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9806 - loss: 0.0549 - val_accuracy: 0.9886 - val_loss: 0.0345
# Epoch 35/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9731 - loss: 0.0712 - val_accuracy: 0.9744 - val_loss: 0.0726
# Epoch 36/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9703 - loss: 0.0811 - val_accuracy: 0.9631 - val_loss: 0.0859
# Epoch 37/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9727 - loss: 0.0726 - val_accuracy: 0.9517 - val_loss: 0.1354
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9857 - loss: 0.0520
# Test Accuracy: 0.9818
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        23
#       banana       1.00      1.00      1.00        21
#    blackgram       0.95      1.00      0.98        20
#     chickpea       1.00      1.00      1.00        26
#      coconut       1.00      1.00      1.00        27
#       coffee       0.89      1.00      0.94        17
#       cotton       1.00      0.94      0.97        17
#       grapes       1.00      1.00      1.00        14
#         jute       0.91      0.87      0.89        23
#  kidneybeans       1.00      1.00      1.00        20
#       lentil       1.00      1.00      1.00        11
#        maize       0.95      0.95      0.95        21
#        mango       1.00      1.00      1.00        19
#    mothbeans       1.00      1.00      1.00        24
#     mungbean       1.00      1.00      1.00        19
#    muskmelon       1.00      1.00      1.00        17
#       orange       1.00      1.00      1.00        14
#       papaya       0.96      1.00      0.98        23
#   pigeonpeas       1.00      0.96      0.98        23
#  pomegranate       1.00      1.00      1.00        23
#         rice       0.94      0.89      0.92        19
#   watermelon       1.00      1.00      1.00        19
#
#     accuracy                           0.98       440
#    macro avg       0.98      0.98      0.98       440
# weighted avg       0.98      0.98      0.98       440

# %%
# 8. SHAP Explainability
print("🔍 SHAP Explainability:")
X_flat = X_selected_seq.reshape(X_selected_seq.shape[0], X_selected_seq.shape[1])
explainer = shap.KernelExplainer(lambda x: model.predict(x.reshape(x.shape[0], top_n, 1)), X_flat[:50])
shap_values = explainer.shap_values(X_flat[:1])
shap.summary_plot(shap_values, X_flat[:1], feature_names=[features[i] for i in top_features_idx])

# 9. LIME Explainability
print("🔍 LIME Explainability:")
explainer_lime = lime.lime_tabular.LimeTabularExplainer(
    training_data=X_flat,
    feature_names=[features[i] for i in top_features_idx],
    class_names=le.classes_,
    mode='classification'
)

lime_exp = explainer_lime.explain_instance(
    data_row=X_flat[0],
    predict_fn=lambda x: model.predict(x.reshape(x.shape[0], top_n, 1)),
    num_features=top_n
)
lime_exp.show_in_notebook()

# 10. Save model
model.save('/mnt/data/xgb_transformer_lstm_model.h5')
print("✅ Model saved as 'xgb_transformer_lstm_model.h5'")
