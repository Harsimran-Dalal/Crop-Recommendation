# %% [markdown]
# # Informer + GRU hybrid model

# %%
import pandas as pd
import numpy as np
import shap
import lime.lime_tabular
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.layers import Input, Dense, GRU, Dropout, LayerNormalization, Add, Conv1D, Lambda, MultiHeadAttention
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping

# Load and preprocess dataset
df = pd.read_csv('/kaggle/input/crop-recommendation-dataset/Crop_recommendation.csv')
features = ['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']
X = df[features].values
y = df['label'].values

le = LabelEncoder()
y_encoded = le.fit_transform(y)
y_cat = to_categorical(y_encoded)

scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)
X_seq = X_scaled.reshape((X_scaled.shape[0], 7, 1))  # (samples, features, 1)

X_train, X_test, y_train, y_test = train_test_split(X_seq, y_cat, test_size=0.2, random_state=42)

# Informer-like Attention block
def informer_block(x, d_model, num_heads, ff_dim, dropout=0.1):
    # ProbSparse is approximated using standard attention with Conv1D key/value compression
    k = Conv1D(filters=d_model, kernel_size=3, padding='same', activation='relu')(x)
    v = Conv1D(filters=d_model, kernel_size=3, padding='same', activation='relu')(x)
    q = x

    attn = MultiHeadAttention(num_heads=num_heads, key_dim=d_model)(q, k, v)
    x = Add()([x, attn])
    x = LayerNormalization()(x)

    ff = Dense(ff_dim, activation='relu')(x)
    ff = Dense(d_model)(ff)
    x = Add()([x, ff])
    x = LayerNormalization()(x)

    return x

# Build Informer + GRU model
def informer_gru_model(input_shape, num_classes, d_model=64, num_heads=4, ff_dim=128, dropout=0.1):
    inp = Input(shape=input_shape)  # (7, 1)

    # Project to d_model dimensions
    x = Conv1D(filters=d_model, kernel_size=1, activation='relu')(inp)

    # Apply multiple Informer blocks
    for _ in range(2):
        x = informer_block(x, d_model, num_heads, ff_dim, dropout)

    # Temporal modeling with GRU
    x = GRU(64, return_sequences=False)(x)

    x = Dropout(dropout)(x)
    x = Dense(64, activation='relu')(x)
    out = Dense(num_classes, activation='softmax')(x)

    return Model(inputs=inp, outputs=out)

# Create and train model
model = informer_gru_model(input_shape=(7, 1), num_classes=y_cat.shape[1])
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
history = model.fit(X_train, y_train, validation_split=0.2, epochs=100, callbacks=[early_stop], verbose=1)

# Evaluate
loss, acc = model.evaluate(X_test, y_test)
print(f" Test Accuracy: {acc:.4f}")

y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(y_test, axis=1)

print("\n Classification Report:")
print(classification_report(y_true, y_pred, target_names=le.classes_))

# Confusion Matrix
plt.figure(figsize=(12, 8))
cm = confusion_matrix(y_true, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=le.classes_, yticklabels=le.classes_)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.tight_layout()
plt.show()

# Accuracy & Loss Plot
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train', marker='o')
plt.plot(history.history['val_accuracy'], label='Val', marker='o')
plt.title("Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.grid(True)
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss', marker='o')
plt.plot(history.history['val_loss'], label='Val Loss', marker='o')
plt.title("Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# Save model
model.save("Informer_gru_crop_recommendation.h5")
print("Model saved as Informer_gru_crop_recommendation.h5")
# Out:
# 2025-11-11 06:43:44.829924: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762843425.029401      38 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762843425.083647      38 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-11 06:43:58.192603: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Epoch 1/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 16s 49ms/step - accuracy: 0.0881 - loss: 3.0301 - val_accuracy: 0.3608 - val_loss: 2.1597
# Epoch 2/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.4809 - loss: 1.8073 - val_accuracy: 0.7841 - val_loss: 0.8718
# Epoch 3/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.8076 - loss: 0.7825 - val_accuracy: 0.8295 - val_loss: 0.5993
# Epoch 4/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.8623 - loss: 0.5091 - val_accuracy: 0.9375 - val_loss: 0.2766
# Epoch 5/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9266 - loss: 0.2819 - val_accuracy: 0.8494 - val_loss: 0.4524
# Epoch 6/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9248 - loss: 0.2476 - val_accuracy: 0.9602 - val_loss: 0.1456
# Epoch 7/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9525 - loss: 0.1748 - val_accuracy: 0.9574 - val_loss: 0.1438
# Epoch 8/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9516 - loss: 0.1599 - val_accuracy: 0.9744 - val_loss: 0.0870
# Epoch 9/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9680 - loss: 0.1244 - val_accuracy: 0.9347 - val_loss: 0.1932
# Epoch 10/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9770 - loss: 0.0998 - val_accuracy: 0.9091 - val_loss: 0.2642
# Epoch 11/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9452 - loss: 0.1654 - val_accuracy: 0.9830 - val_loss: 0.0606
# Epoch 12/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9726 - loss: 0.0874 - val_accuracy: 0.9460 - val_loss: 0.1626
# Epoch 13/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9468 - loss: 0.1546 - val_accuracy: 0.9375 - val_loss: 0.1769
# Epoch 14/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9519 - loss: 0.1324 - val_accuracy: 0.9801 - val_loss: 0.0713
# Epoch 15/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9754 - loss: 0.0833 - val_accuracy: 0.9801 - val_loss: 0.0558
# Epoch 16/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9776 - loss: 0.0700 - val_accuracy: 0.9688 - val_loss: 0.1257
# Epoch 17/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9815 - loss: 0.0628 - val_accuracy: 0.9801 - val_loss: 0.0648
# Epoch 18/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9847 - loss: 0.0551 - val_accuracy: 0.9091 - val_loss: 0.2530
# Epoch 19/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9539 - loss: 0.1463 - val_accuracy: 0.9858 - val_loss: 0.0477
# Epoch 20/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9824 - loss: 0.0481 - val_accuracy: 0.9716 - val_loss: 0.0712
# Epoch 21/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9875 - loss: 0.0502 - val_accuracy: 0.9886 - val_loss: 0.0338
# Epoch 22/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9866 - loss: 0.0405 - val_accuracy: 0.9773 - val_loss: 0.0663
# Epoch 23/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9744 - loss: 0.0765 - val_accuracy: 0.9744 - val_loss: 0.0778
# Epoch 24/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9788 - loss: 0.0788 - val_accuracy: 0.9716 - val_loss: 0.0953
# Epoch 25/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9689 - loss: 0.0920 - val_accuracy: 0.9659 - val_loss: 0.1052
# Epoch 26/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9704 - loss: 0.0762 - val_accuracy: 0.9659 - val_loss: 0.0892
# Epoch 27/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9824 - loss: 0.0626 - val_accuracy: 0.9773 - val_loss: 0.0561
# Epoch 28/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9840 - loss: 0.0532 - val_accuracy: 0.9886 - val_loss: 0.0359
# Epoch 29/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9885 - loss: 0.0447 - val_accuracy: 0.9631 - val_loss: 0.1033
# Epoch 30/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9726 - loss: 0.0854 - val_accuracy: 0.9801 - val_loss: 0.0664
# Epoch 31/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9759 - loss: 0.0640 - val_accuracy: 0.9602 - val_loss: 0.1021
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9725 - loss: 0.0691
#  Test Accuracy: 0.9750
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step
#
#  Classification Report:
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        23
#       banana       1.00      1.00      1.00        21
#    blackgram       1.00      0.95      0.97        20
#     chickpea       1.00      1.00      1.00        26
#      coconut       1.00      1.00      1.00        27
#       coffee       0.94      1.00      0.97        17
#       cotton       1.00      1.00      1.00        17
#       grapes       1.00      1.00      1.00        14
#         jute       0.86      0.83      0.84        23
#  kidneybeans       1.00      1.00      1.00        20
#       lentil       0.73      1.00      0.85        11
#        maize       1.00      1.00      1.00        21
#        mango       1.00      1.00      1.00        19
#    mothbeans       1.00      0.88      0.93        24
#     mungbean       1.00      1.00      1.00        19
#    muskmelon       1.00      1.00      1.00        17
#       orange       1.00      1.00      1.00        14
#       papaya       0.96      1.00      0.98        23
#   pigeonpeas       1.00      1.00      1.00        23
#  pomegranate       1.00      1.00      1.00        23
#         rice       0.89      0.84      0.86        19
#   watermelon       1.00      1.00      1.00        19
#
#     accuracy                           0.97       440
#    macro avg       0.97      0.98      0.97       440
# weighted avg       0.98      0.97      0.98       440
# Model saved as Informer_gru_crop_recommendation.h5
